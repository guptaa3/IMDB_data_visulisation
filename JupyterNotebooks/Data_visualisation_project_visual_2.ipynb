# %% [markdown]
# # Data Visualisation project - visualisation 2

# %% [markdown]
# Importing necessary libraries and the data set

# %%
import pandas as pd
import numpy as np

# %%
from bokeh.plotting import figure , show
from bokeh.layouts import layout, widgetbox, row
from bokeh.models import ColumnDataSource, Div, HoverTool, Legend, CategoricalColorMapper
from bokeh.models.widgets import Slider, Select
from bokeh.io import curdoc, output_notebook
from bokeh.models.glyphs import MultiLine

# %%
from bokeh.transform import factor_cmap
from bokeh.palettes import Colorblind

# %%
#output_notebook()

# %%
dataset_names = pd.read_csv('I:/DCU/SEM1/Lectures/Data Management & Visualisation - CA682 Suzanne Little/project/imdb_project/cleaned data/names.csv',index_col= 'nconst')
dataset_titles_ratings = pd.read_csv('I:/DCU/SEM1/Lectures/Data Management & Visualisation - CA682 Suzanne Little/project/imdb_project/cleaned data/titles_basic_rating.csv',index_col= 'tconst')
dataset_titles_prin = pd.read_csv('I:/DCU/SEM1/Lectures/Data Management & Visualisation - CA682 Suzanne Little/project/imdb_project/cleaned data/titles_principle.csv',index_col= 'tconst')

# %%
#dataset_titles_ratings.head()
# Out:
#           titleType            primaryTitle           originalTitle  isAdult  \
# tconst
# tt0000001     short              Carmencita              Carmencita        0
# tt0000002     short  Le clown et ses chiens  Le clown et ses chiens        0
# tt0000003     short          Pauvre Pierrot          Pauvre Pierrot        0
# tt0000004     short             Un bon bock             Un bon bock        0
# tt0000005     short        Blacksmith Scene        Blacksmith Scene        0
#
#           startYear runtimeMinutes       genre1  genre2  averageRating  \
# tconst
# tt0000001      1894              1  Documentary   Short            5.8
# tt0000002      1892              5    Animation   Short            6.4
# tt0000003      1892              4    Animation  Comedy            6.6
# tt0000004      1892             \N    Animation   Short            6.4
# tt0000005      1893              1       Comedy   Short            6.2
#
#            numVotes
# tconst
# tt0000001      1441
# tt0000002       174
# tt0000003      1043
# tt0000004       104
# tt0000005      1740

# %%
#dataset_names.head()
# Out:
#                primaryName knownForTitles1 knownForTitles2 knownForTitles3  \
# nconst
# nm0000001     Fred Astaire       tt0053137       tt0050419       tt0043044
# nm0000002    Lauren Bacall       tt0037382       tt0071877       tt0117057
# nm0000003  Brigitte Bardot       tt0049189       tt0054452       tt0057345
# nm0000004     John Belushi       tt0072562       tt0077975       tt0080455
# nm0000005   Ingmar Bergman       tt0060827       tt0050986       tt0050976
#
#           knownForTitles4
# nconst
# nm0000001       tt0072308
# nm0000002       tt0038355
# nm0000003       tt0059956
# nm0000004       tt0078723
# nm0000005       tt0083922

# %% [markdown]
# We want to use the data for these 5 genres for our visualisation

# %%
genres = ['Comedy','Romance', 'Drama','Horror','Action']

# %%
#dataset_titles_prin.head()

# %%
dataset_titles_ratings = dataset_titles_ratings.drop(dataset_titles_ratings[(dataset_titles_ratings['genre1'] != 'Action') & (dataset_titles_ratings['genre1'] != 'Comedy')
                                             & (dataset_titles_ratings['genre1'] != 'Horror') & (dataset_titles_ratings['genre1'] != 'Romance')
                                             & (dataset_titles_ratings['genre1'] != 'Drama')].index)

# %% [markdown]
# Lets look at data after the year 1950

# %%
dataset_titles_ratings['startYear'] = pd.to_numeric(dataset_titles_ratings['startYear'])
dataset_titles_ratings = dataset_titles_ratings.drop(dataset_titles_ratings[(dataset_titles_ratings['startYear'] < 1950)].index)

# %% [markdown]
# Removing values other than movies, as we want to see the trend of movies across genres

# %%
dataset_titles_ratings = dataset_titles_ratings.drop(dataset_titles_ratings[(dataset_titles_ratings['titleType']!='movie')].index)

# %%
#dataset_titles_ratings.head()

# %% [markdown]
# Grouping the genre based on year and genre

# %%
dataset_grouped = dataset_titles_ratings.groupby(['startYear','genre1'], as_index=False).agg({"primaryTitle": "count"})

# %%
#dataset_grouped.head()

# %% [markdown]
# Separting the data set into specific genres for easy access of data

# %%
dataset_action = dataset_grouped.drop(dataset_grouped[(dataset_grouped['genre1'] != "Action")].index)

# %%
dataset_Comedy = dataset_grouped.drop(dataset_grouped[(dataset_grouped['genre1'] != "Comedy")].index)

# %%
dataset_Drama = dataset_grouped.drop(dataset_grouped[(dataset_grouped['genre1'] != "Drama")].index)
dataset_Romance = dataset_grouped.drop(dataset_grouped[(dataset_grouped['genre1'] != "Romance")].index)

# %%
dataset_Horror = dataset_grouped.drop(dataset_grouped[(dataset_grouped['genre1'] != "Horror")].index)

# %%
#dataset_action.head()

# %% [markdown]
# Creating 4 sources of data, for each genre

# %%
source_action= ColumnDataSource(data=dict(x=dataset_action['startYear'], y=dataset_action['primaryTitle'], genre=dataset_action['genre1']))
source_comedy= ColumnDataSource(data=dict(x=dataset_Comedy['startYear'], y=dataset_Comedy['primaryTitle'], genre=dataset_Comedy['genre1']))
source_drama= ColumnDataSource(data=dict(x=dataset_Drama['startYear'], y=dataset_Drama['primaryTitle'], genre=dataset_Drama['genre1']))
source_romance= ColumnDataSource(data=dict(x=dataset_Romance['startYear'], y=dataset_Romance['primaryTitle'], genre=dataset_Romance['genre1']))
source_horror= ColumnDataSource(data=dict(x=dataset_Horror['startYear'], y=dataset_Horror['primaryTitle'], genre=dataset_Horror['genre1']))

# %% [markdown]
# Setting the parameters for the figure of visualisation.

# %%
#years with highest number of releases genre wise
p = figure(plot_height=700, plot_width=800, title="Genre wise trend of number of movies over the years" ,toolbar_location=None, x_range=(1950,2018),y_range=(0,2500))

# %%
p.line(x='x', y='y',source =source_action, line_color='darkblue', line_width=2, legend = 'genre')
p.line(x='x', y='y',source =source_romance, line_color='deeppink', line_width=2, legend = 'genre')
p.line(x='x', y='y',source =source_horror, line_color='darkgreen', line_width=2, legend = 'genre')
p.line(x='x', y='y',source =source_comedy, line_color='yellow', line_width=2, legend = 'genre')
p.line(x='x', y='y',source =source_drama, line_color='darkred', line_width=2, legend = 'genre')
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='3b8a148b-ab4f-4489-8d65-87a6a60b5608',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='687d5944-35e0-4f34-8278-cfdd6181a2aa',
#         callback=None,
#         data={'y': [288,
#           321,
#           276,
#           324,
#           347,
#           335,
#           384,
#           418,
#           400,
#           415,
#           410,
#           452,
#           458,
#           418,
#           453,
#           471,
#           460,
#           461,
#           553,
#           631,
#           609,
#           561,
#           529,
#           536,
#           555,
#           498,
#           497,
#           532,
#           516,
#           526,
#           535,
#           536,
#           557,
#           565,
#           587,
#           566,
#           624,
#           642,
#           644,
#           594,
#           597,
#           621,
#           539,
#           551,
#           557,
#           598,
#           606,
#           680,
#           687,
#           765,
#           811,
#           884,
#           905,
#           948,
#           1145,
#           1264,
#           1380,
#           1374,
#           1584,
#           1756,
#           1766,
#           1870,
#           1941,
#           1941,
#           1957,
#           2110,
#           2021,
#           2091,
#           1552,
#           1],
#          'genre': ['Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama',
#           'Drama'],
#          'x': [1950,
#           1951,
#           1952,
#           1953,
#           1954,
#           1955,
#           1956,
#           1957,
#           1958,
#           1959,
#           1960,
#           1961,
#           1962,
#           1963,
#           1964,
#           1965,
#           1966,
#           1967,
#           1968,
#           1969,
#           1970,
#           1971,
#           1972,
#           1973,
#           1974,
#           1975,
#           1976,
#           1977,
#           1978,
#           1979,
#           1980,
#           1981,
#           1982,
#           1983,
#           1984,
#           1985,
#           1986,
#           1987,
#           1988,
#           1989,
#           1990,
#           1991,
#           1992,
#           1993,
#           1994,
#           1995,
#           1996,
#           1997,
#           1998,
#           1999,
#           2000,
#           2001,
#           2002,
#           2003,
#           2004,
#           2005,
#           2006,
#           2007,
#           2008,
#           2009,
#           2010,
#           2011,
#           2012,
#           2013,
#           2014,
#           2015,
#           2016,
#           2017,
#           2018,
#           2019]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='993c74f8-86fb-4380-bc59-4e6ca0034471',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='bfcac64a-597c-4375-82e5-320fd7a89ede',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.glyphs.Line(
#         id='1b23ce62-5441-4d15-8519-5651012a7a3b',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha=1.0,
#         line_cap='butt',
#         line_color='darkred',
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width=2,
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.glyphs.Line(
#         id='c8f0a402-3a29-4ff0-b2ba-6bb8e47b4194',
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha=0.1,
#         line_cap='butt',
#         line_color='#1f77b4',
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='miter',
#         line_width=2,
#         name=None,
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='3fdbf428-482d-41ea-bd8f-e4a114542d56',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='687d5944-35e0-4f34-8278-cfdd6181a2aa',
#             callback=None,
#             data={'y': [288,
#               321,
#               276,
#               324,
#               347,
#               335,
#               384,
#               418,
#               400,
#               415,
#               410,
#               452,
#               458,
#               418,
#               453,
#               471,
#               460,
#               461,
#               553,
#               631,
#               609,
#               561,
#               529,
#               536,
#               555,
#               498,
#               497,
#               532,
#               516,
#               526,
#               535,
#               536,
#               557,
#               565,
#               587,
#               566,
#               624,
#               642,
#               644,
#               594,
#               597,
#               621,
#               539,
#               551,
#               557,
#               598,
#               606,
#               680,
#               687,
#               765,
#               811,
#               884,
#               905,
#               948,
#               1145,
#               1264,
#               1380,
#               1374,
#               1584,
#               1756,
#               1766,
#               1870,
#               1941,
#               1941,
#               1957,
#               2110,
#               2021,
#               2091,
#               1552,
#               1],
#              'genre': ['Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama',
#               'Drama'],
#              'x': [1950,
#               1951,
#               1952,
#               1953,
#               1954,
#               1955,
#               1956,
#               1957,
#               1958,
#               1959,
#               1960,
#               1961,
#               1962,
#               1963,
#               1964,
#               1965,
#               1966,
#               1967,
#               1968,
#               1969,
#               1970,
#               1971,
#               1972,
#               1973,
#               1974,
#               1975,
#               1976,
#               1977,
#               1978,
#               1979,
#               1980,
#               1981,
#               1982,
#               1983,
#               1984,
#               1985,
#               1986,
#               1987,
#               1988,
#               1989,
#               1990,
#               1991,
#               1992,
#               1993,
#               1994,
#               1995,
#               1996,
#               1997,
#               1998,
#               1999,
#               2000,
#               2001,
#               2002,
#               2003,
#               2004,
#               2005,
#               2006,
#               2007,
#               2008,
#               2009,
#               2010,
#               2011,
#               2012,
#               2013,
#               2014,
#               2015,
#               2016,
#               2017,
#               2018,
#               2019]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='993c74f8-86fb-4380-bc59-4e6ca0034471',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='bfcac64a-597c-4375-82e5-320fd7a89ede',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
#show(p)

# %%
p.add_tools(HoverTool( tooltips=[
    ("Number of Movies", "@y"),
    ("Genre", "@genre"),
    ("Year","@x")
    ]
    ))

p.legend.location = (322,550)
p.legend.orientation = "horizontal"
p.legend.click_policy="hide"

# %%
p.xaxis.axis_label = 'Year'
p.yaxis.axis_label = 'Number of movies'
p.xaxis.axis_label_standoff = 10
p.xaxis.axis_label_text_font_size ="16pt"
p.yaxis.axis_label_text_font_size= "16pt"
p.title.text_font_size = '20pt'
p.title.align = "center"
p.title.offset =10

# %%
sizing_mode = 'fixed'
inputs = widgetbox(sizing_mode=sizing_mode)
layout = row(p,inputs)

# %%
curdoc().add_root(layout)
curdoc().title = "Movie Genres"

# %%
#show(layout)
